# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanachellamuthu/python/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Literal
import os
import sys

print("hello, world")

if 5 > 2:
  print("the number is greater than 2")

x = 5
y = "hello world "
z = 'you can ' # "aa " and ' aa' both are same
print(x , y , z )
print (type(x) , type(y)) # to know what type of datatype

x = int (5) # casting
y = float(9.00)
Z = str(3) # python is case sentitive


print (x, y, Z )

print(sys.version)


''' variable shouldn' be start with number and shouldn't have space and its case sentitivce '''

myFirstName = 'keerthANA' # variables can be camel case
MyLastName = 'Chellamuthu' # variables can be pasal case

print (myFirstName , MyLastName)

x = y = z ="orange" # canassign one variable to all variables
print (z)

Fruits =["apple", "banana" , "oRANGES"] # collections can be triple or list is also called unpack the collections
x, y, z = Fruits

print(x, y, z)
print(x+y+z)# to print without spaces


# multiple lines

a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# hello, world
# the number is greater than 2
# 5 hello world  you can
# <class 'int'> <class 'str'>
# 5 9.0 3
# 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# keerthANA Chellamuthu
# orange
# apple banana oRANGES
# applebananaoRANGES
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
set1 = {"apple", "banana", "cherry"} # set are in {}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

print("banana" in set1)

for x in set1:   # we can access set using in
  print("cherry" in set1)

set1.update(set2)
print(set1)
'''
set3 = set1.union(set2) # all in sets
set4 = set1.differnce(set2) # left outer join
set5 = set1 | set2 # union
set6 = set1-set2 # difference
set7 = set1&set2 # intersection
set8 = set1.intersection_update(set2) # symmnetric intersection is oppsite of intersection also presents as ^
print(set3)
'''


thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict) # stores the values in key and values and changable , uniquie

dict1 = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

dict1.update({"car_type" :"electric"})
print(dict)

x = dict1.get("colour") # ti display the specific values of the key
y = dict1.keys() # to display all the list ofthe key
z = dict1.values() # to display all the values
w = dict1.items() # to display all keys and its values

dict1["brand"] = "bmw"

print(dict1)

print(w)
print(z)
print(y)
print(x)



for w in dict1:
  print(w)

for y,z in dict1.items(): # to get both keys and vaues we need two variables in loop
  print(y,":" ,z)

myfamily = {  # dict contains another dic is called nested dictionary
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily["child2"]["name"]) # access the values in  nested dictionary
# Out:
# True
# True
# True
# True
# {1, 3, 5, 7, 9, 'banana', 'cherry', 'apple'}
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# <class 'dict'>
# {'brand': 'bmw', 'electric': False, 'year': 1964, 'colors': ['red', 'white', 'blue'], 'car_type': 'electric'}
# dict_items([('brand', 'bmw'), ('electric', False), ('year', 1964), ('colors', ['red', 'white', 'blue']), ('car_type', 'electric')])
# dict_values(['bmw', False, 1964, ['red', 'white', 'blue'], 'electric'])
# dict_keys(['brand', 'electric', 'year', 'colors', 'car_type'])
# None
# brand
# electric
# year
# colors
# car_type
# brand : bmw
# electric : False
# year : 1964
# colors : ['red', 'white', 'blue']
# car_type : electric
# Tobias

# %%
x = 200
print(isinstance(x, int)) # isinstance () check the obect has datatype

x *= 3	# x= x+3

thislist = ("apple","banana","mango")
print(thislist)
print(len(thislist))
print(list(thislist)) # list() is the constructor
list1 = ["abc", 34, True, 40, "male"] # contain different type of datatype
print(type(list1))

'''List is a collection which is ordered and changeable. Allows duplicate members.
Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
Dictionary is a collection which is ordered** and changeable. No duplicate members.'''

list2 =['a','b','c','d','e'] # list can be indexed
print(list2[2:5])
print(list2[-5:-2])
list2.insert (3 ,"z")
list2[1] = "2" # list values can be changed nad we can insert usig insert()
print(list2)

list2.append("g") # to add one item in list
list3 = ("k"'l') # to add multiple item in list extend() creating another list and adding to the exiting list
list2.extend(list3)
print(list2)

list2.remove("k")
list2.pop(1)  # deletes the last item
'''del list3
list2.clear()'''
'''
for i in list3:
  print(i)

 i = 0
while (i<= len(list2)):
  print(i)'''

tuple1 = ('aaple','banana') # we can only change tuple as list and then we can add or else tuple is immutable

x = list(tuple1)
x.append( "orange")

tuple1 = tuple(x)
print(tuple1)


tuple2 = (2, 3, 5 )
''
z = tuple2 + tuple1 # we can add two tuple
print(z)
''

(x,y,z) = tuple2 # unpaxkinf tuple (by assigning variable to values in tuple )
print(x)

s = (tuple1 * 2)

print(tuple1)
# Out:
# True
# ('apple', 'banana', 'mango')
# 3
# ['apple', 'banana', 'mango']
# <class 'list'>
# ['c', 'd', 'e']
# ['a', 'b', 'c']
# ['a', '2', 'c', 'z', 'd', 'e']
# ['a', '2', 'c', 'z', 'd', 'e', 'g', 'k', 'l']
# ('aaple', 'banana', 'orange')
# (2, 3, 5, 'aaple', 'banana', 'orange')
# 2
# ('aaple', 'banana', 'orange')

# %%
a = "Hello, World!" # array of string
print(a[1])

for x in "banana": # looping in string
  print(x)

a = "Hello, World!" # lengh
print(len(a))

txt = "The best things in life are free!" # checkinfg in string
print("free" in txt)

txt = "The best things in life are free!" # if in string
if "free" in txt:
  print("Yes, 'free' is present.")

txt = "The best things in life are free!" #char is not in
print("expensive" not in txt)

b = "Hello, World!" # slicing the string
print(b[2:5])
print(b[:5])
print(b[2:])
print(b[-2:-5]) # negetative indexing counts from last

a = "Hello, World!"
b = "big data"
print(a.upper())
print(b.lower())
print(a.strip()) # removes whitescapes
print(a.split("e"))
print(a.replace("l" ,"2"))
print(a+b)

length = 56
print(f"the length is {length}") # f can be used before format string

price = 59
txt = (f"The price is {price} dollars")
print(txt)

price = 59
txt = f"The price is {price:.2f} dollars" # can add 2 floating decimal with help of format
print( txt)
# Out:
# e
# b
# a
# n
# a
# n
# a
# 13
# True
# Yes, 'free' is present.
# True
# llo
# Hello
# llo, World!
#
# HELLO, WORLD!
# big data
# Hello, World!
# ['H', 'llo, World!']
# He22o, Wor2d!
# Hello, World!big data
# the length is 56
# The price is 59 dollars
# The price is 59.00 dollars

# %%
''' conversion '''

y=2
x=4.7
z=1j

a = float(y)

print(a)



# Literal
a = int("3") # z will be 3
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'
print(x,y, z)
print(a)
# Out:
# 2.0
# 4.7 2 3.0
# 3

# %%
# datatypes

x = "Hello World"	#str
x = 2 #int
x = 20.5	#float
x = 1j    #	complex
x = ["apple", "banana", "cherry"]  	#list
x = ("apple", "banana", "cherry")  	#tuple
x = range(6)	#range
x = {"name" : "John", "age" : 36}	#dict
x = {"apple", "banana", "cherry"}	#set
x = frozenset({"apple", "banana", "cherry"})	#frozenset
x = True	#bool
x = b"Hello"	#bytes
x = bytearray(5) #	bytearray
x = memoryview(bytes(5))	#memoryview
x = None	# NoneType

print(x)
# Out:
# None

# %%
x = "awesome" # global variable

def myfunc():
  print("Python is " + x)

myfunc()

x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x) # local variabl
myfunc()
print("Python is " + x)
x = "awesome"
def myfunc():
  global x # Global is the keybol to declare the global variable
  x = "fantastic"
myfunc()

print("Python is " + x)
# Out:
# Python is awesome
# Python is fantastic
# Python is awesome
# Python is fantastic

# %%
# functions
from ast import Pass
a = 200
b = 33
c = 33
if b > a:
  print("b is greater than a")
elif a == b: # else if is written as elif
  print("a and b are equal")
else:
  print("a is greater than b")

if (a > b ): print(b) # shorthand

print(a) if (a < b) else print(" b is greater than a") # shorthand also ternary condition

if (a<b) and (b ==c): # likewise we can use or and not
  pass

x = 41 # nestedif
if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

a = 33  # if statement retuens cannot be empty
b = 200

if b > a:
  pass
# Out:
# a is greater than b
# 33
#  b is greater than a
# Above ten,
# and also above 20!

# %%
for x in range(6): #range means 0 to 5 # break is used to break the statement and continue is used to jump particular value in system
  if x == 3: continue
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 4
# 5
# Finally finished!

# %%
i = 0
while ( i<7): # we can use if statement in while and we can even ise break and contiune in whike loop statement
 print(i)
 break
 i += 1

if i==3:
  pass
else:
  print("i is greater than  7")
# Out:
# 0
# i is greater than  7

# %%
def percentage(x,y): # parameters
   Z = (x/y)*100
   z = round(Z, 2)  # to round the float function round() is used

   print(f"the number of days is  {z}%") # string formatting

percentage(10,365.5) # arguments

def my_function(country = "Norway"): # we can set default value for the function when no arguments is passed
  print("I am from " + country)

my_function("Sweden")
my_function("India")
my_function()
my_function("Brazil")

def number(x):
  return 5*x  # inorder to return the value in function return keyword is used
  print(x)
number(2)

def create_user(username, /, admin=False): #  "/" symbol for positioning th agruments
   print(username , admin )
# Out:
# the number of days is  2.74%
# I am from Sweden
# I am from India
# I am from Norway
# I am from Brazil
# john_doe False
# admin_user True
# (1, 3, 5, 7, 9)
# 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4a5b41711a28> in <cell line: 0>()
#      46   print(a + b + c + d)
#      47
# ---> 48 my_function(5, 6, c , d=8)
#      49
#      50 def my_function1(a, b, /, *,c, d): # "*" symbol is used before comma we have to pass the arguments as keybord (means value has to be assigned)
#
# NameError: name 'c' is not defined

# %%
def tri_recursion(k):
  if(k > 0):
    result = k + tri_recursion(k - 1) # function calls itself recurrsivelly (it calls repectively untill the base condition met )
    print(result)
  else:
    result = 0
  return result

print("Recursion Example Results:")
tri_recursion(6)
# Out:
# Recursion Example Results:
# 1
# 3
# 6
# 10
# 15
# 21
# 21

# %%
"""Creates a new user.

  Args:
    username: The username for the new user.
    admin: Whether the user should have administrator privileges (default: False).
"""

create_user("john_doe")  # Creates a user named "john_doe" with default admin privileges (False)
create_user("admin_user", admin=True)  # Creates a user named "admin_user" with admin privileges

def aa(*a): # we can use * to send list of args to the parameter
   print(a)

aa(1, 3, 5, 7, 9)

def err3(a,*,b): # if * symbol is used before comma we have to pass the arguments as keybord (means value has to be assigned) that argument is called positional argument
  c=a*b
  print(c)
err3(3,b=5)

def my_function(a, b, /, c, d): # "/" symbol the last arguments should be positional argument (means arguments must assign to value before passed )
  print(a + b + c + d)

my_function(5, 6, c , d=8)

def my_function1(a, b, /, *,c, d): # "*" symbol is used before comma we have to pass the arguments as keybord (means value has to be assigned)
  print(a + b + c + d)

my_function1(5, 6, c=2 , d=8)
# Out:
# john_doe False
# admin_user True
# (1, 3, 5, 7, 9)
# 15
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-78f59607f641> in <cell line: 0>()
#      22   print(a + b + c + d)
#      23
# ---> 24 my_function(5, 6, c , d=8)
#      25
#      26 def my_function1(a, b, /, *,c, d): # "*" symbol is used before comma we have to pass the arguments as keybord (means value has to be assigned)
#
# NameError: name 'c' is not defined

# %%
#  lambda function
def myfunc(n):
  return lambda a : a * n # experession returns value to argument before : (lambda function)

mytripler = myfunc(4) # means creating factor for cloutse

print(mytripler(11)) # clourse means tripples of 11 means 11*3

def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)
mytripler = myfunc(3)

print(mydoubler(11))
print(mytripler(11))

x = lambda a, b : a - b
print(x(5, 3))
# Out:
# 44
# 22
# 33
# 2

# %%
'''Oops
anything can be specified as object and object has behaviour and properties eg mam (object is the instance of the class)
class the blueprint or instance or templete of the object eg : application for college (many people (object) can fill their details in application form (class))
for each person needs each copy of application that copy for each object (person) is called (instantiation )
'''
''''
class car():

    def __init__(self): # it initicates when the object of the class created
       print("this is construcor")
       self.car_Model="BMW" # attributes or variables
       self.Car_Size= 100
       self.Car_mileage = 0.00


def moveforward(self): # methods ( functions are called as methods in oops) # self is keyword which allocate teh memory for the argument
  print(" the car is moving forward")

def Movebackwards(self):
  print(" the car is moving backwards")

car1= car() # instantiation ( creating the instance of the class = object creation )
car2= car()
var_1 = car1.car_Model # assigning the variable to the obect so trhat we can abl eto access the object
print(var_1)

var_2 = car2.Car_mileage
car2.Car_mileage = 100.00
print(car2.Car_mileage)
'''

class BankAccount:

    def __init__(self): # self is a object for constructor and it can have nay name
      self.Cust_name="xxx"
      self.Account_Num=0.00
      self.Balance=0.00

def __del__(self): # cleanup and garbage collection
   print("this is a destructor")


Cust_1= BankAccount()
Cust_2= BankAccount()

x = Cust_1.Cust_name
Cust_1.Cust_name = "Keerthi"
print(Cust_1.Cust_name)

y=Cust_2.Cust_name
print(Cust_2.Cust_name)

del y # only deletes the local variable
# Out:
# Keerthi
# xxx

# %%
# pandas

import pandas as pd
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
print(pd. __version__) # __version__ attribute of the pandas library, which stores the installed version number, and prints it to the console.
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# 2.2.2
# 0    1
# 1    0
# 2    2
# dtype: int64

# %%
a = [1,0,2] # in pandas series is consider as coloumn
x=pd.Series(a)
x= pd.Series(a, index=["x","y","z"]) # in Series "s" should be capital and index is label as x , y , z using series.index[] function
print(x)
# Out:
# x    1
# y    0
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390} # in dict keys are labelled as index

myvar = pd.Series(calories)
print(myvar)
myvar = pd.Series(calories,index=["day1","day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
# day1    420
# day2    380
# dtype: int64

# %%
z= { "x":[1,2,3] ,"y":[5,6,7]} # for multi dimentional array we used Dataframe function in pandas
Myvar = pd.DataFrame(z)
print(Myvar)
'''
z= [ [1,2,3] ,[5,6,7]] # its not the dict so it label the index  in rows as 0, 1, 2, 3...
Myvar = pd.DataFrame(z)
print(Myvar)
print(Myvar.loc[0]) # loc() attribute used to display or fetch data in  the rows
'''
print(Myvar.loc["x"])
# Out:
#    x  y
# 0  1  5
# 1  2  6
# 2  3  7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-e51100cb11db> in <cell line: 0>()
#       8 print(Myvar.loc[0]) # loc() attribute used to display or fetch data in  the rows
#       9 '''
# ---> 10 print (Myvar.loc["x"])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1429         # fall thru to straight lookup
#    1430         self._validate_key(key, axis)
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv') # load CSV files

print(df)

# %%
import pandas as pd

df = pd.read_json('data.json')

print(df.to_string()) # to_string() function or attribute is used to display all rows fetch in the json file without that it only display first 10 rows and in end display number od rows
#head() display first five rows
# tail()display last five rows
#info(), that gives you more information about the data set

# %%
import requests  # To send HTTP requests
import pandas as pd  # To handle data and create DataFrames
import json  # To handle JSON data

# Install required libraries (in case you need them)
# !pip install pandas
# !pip install requests

# %%
API_key = "995b0619450854000271abc5cf7ee0e8"
url = f'http://api.openweathermap.org/data/2.5/forecast?id=524901&appid={API_key}'
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/forecast?id=524901&appid=995b0619450854000271abc5cf7ee0e8

# %%
# Send an HTTP GET request to the OpenWeather API using the constructed URL
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
data = response.json() # Converts the JSON response into a Python dictionary

# %%
print(type(data)) ## This helps to confirm that the response was parsed correctly and is now in dictionary format
# Out:
# <class 'dict'>

# %%
# Use json.dumps() to pretty-print the JSON data with an indentation of 4 spaces.
print(data)
print(json.dumps(data,indent=4))
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1737126000, 'main': {'temp': 276.75, 'feels_like': 272.58, 'temp_min': 274.99, 'temp_max': 276.75, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 996, 'humidity': 77, 'temp_kf': 1.76}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 5.32, 'deg': 314, 'gust': 12.19}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-17 15:00:00'}, {'dt': 1737136800, 'main': {'temp': 276.13, 'feels_like': 272.11, 'temp_min': 274.88, 'temp_max': 276.13, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 998, 'humidity': 81, 'temp_kf': 1.25}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 4.72, 'deg': 325, 'gust': 9.42}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-01-17 18:00:00'}, {'dt': 1737147600, 'main': {'temp': 275.01, 'fee
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
# Create an empty list to store weather data
# Loop through the data and extract useful weather information
weather_data =[]
for item in data['list']:
        weather_data.append({
        "datetime": item.get("dt_txt", ""),  # Date and time of the forecasted data
        "temp": item.get("main", {}).get("temp", 0),  # Temperature # getting value from dict and then again getting value from dict
        "feels_like": item.get("main", {}).get("feels_like", 0),  # Feels like temperature
        "temp_min": item.get("main", {}).get("temp_min", 0),  # Minimum temperature
        "temp_max": item.get("main", {}).get("temp_max", 0),  # Maximum temperature
        "pressure": item.get("main", {}).get("pressure", 0),  # Atmospheric pressure
        "humidity": item.get("main", {}).get("humidity", 0),  # Humidity percentage
        "weather_main": item.get("weather", [{}])[0].get("main", ""),  # Main weather condition (e.g., Rain, Snow)
        "weather_description": item.get("weather", [{}])[0].get("description", ""),  # Detailed weather description
        "clouds": item.get("clouds", {}).get("all", 0),  # Cloudiness percentage
        "wind_speed": item.get("wind", {}).get("speed", 0),  # Wind speed
        "wind_deg": item.get("wind", {}).get("deg", 0),  # Wind direction (degrees)
        "visibility": item.get("visibility", 0),  # Visibility in meters
        "pop": item.get("pop", 0),  # Probability of precipitation
        "snow_3h": item.get("snow", {}).get("3h", 0),  # Snowfall in the last 3 hours (if any)
    })

# Create a pandas DataFrame
df = pd.DataFrame(weather_data)

# Display the DataFrame
print(df.head())
print(df.to_string())
print(df.tail())


# convert into csv or desired file(in ETL its loading process )
df.to_csv
df.to_excel
df.to_numpy
# Out:
#               datetime    temp  feels_like  temp_min  temp_max  pressure  \
# 0  2025-01-17 15:00:00  276.75      272.58    274.99    276.75      1016
# 1  2025-01-17 18:00:00  276.13      272.11    274.88    276.13      1017
# 2  2025-01-17 21:00:00  275.01      271.72    274.14    275.01      1017
# 3  2025-01-18 00:00:00  274.09      270.74    274.09    274.09      1017
# 4  2025-01-18 03:00:00  274.24      270.57    274.24    274.24      1015
#
#    humidity weather_main weather_description  clouds  wind_speed  wind_deg  \
# 0        77       Clouds     overcast clouds     100        5.32       314
# 1        81       Clouds     overcast clouds     100        4.72       325
# 2        89       Clouds     overcast clouds     100        3.20       295
# 3        92       Clouds     overcast clouds     100        3.04       276
# 4        91       Clouds     overcast clouds     100        3.48       249
#
#    visibility  pop  snow_3h
# 0       10000  0.0      0.0
# ...

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of                datetime    temp  feels_like  temp_min  temp_max  pressure  \
# 0   2025-01-17 15:00:00  276.75      272.58    274.99    276.75      1016
# 1   2025-01-17 18:00:00  276.13      272.11    274.88    276.13      1017
# 2   2025-01-17 21:00:00  275.01      271.72    274.14    275.01      1017
# 3   2025-01-18 00:00:00  274.09      270.74    274.09    274.09      1017
# 4   2025-01-18 03:00:00  274.24      270.57    274.24    274.24      1015
# 5   2025-01-18 06:00:00  274.41      270.18    274.41    274.41      1011
# 6   2025-01-18 09:00:00  274.64      269.80    274.64    274.64      1008
# 7   2025-01-18 12:00:00  274.42      269.57    274.42    274.42      1006
# 8   2025-01-18 15:00:00  273.95      268.94    273.95    273.95      1007
# 9   2025-01-18 18:00:00  274.09      268.91    274.09    274.09      1008
# 10  2025-01-18 21:00:00  272.86      267.22    272.86    272.86      1009
# ...

# %%
print(df.count())
# Out:
# datetime               40
# temp                   40
# feels_like             40
# temp_min               40
# temp_max               40
# pressure               40
# humidity               40
# weather_main           40
# weather_description    40
# clouds                 40
# wind_speed             40
# wind_deg               40
# visibility             40
# pop                    40
# snow_3h                40
# dtype: int64

# %%
! pip install pyspark

'''  pyspark.sql from SparkSession

spark = SparkSession.builder.enableHiveSupport().master('local').getOrCreate()''import'

'''SparkSession.builder: Starts the SparkSession builder.
.enableHiveSupport(): Enables integration with Apache Hive.
.master('local'): Sets the Spark master URL to local mode.
.getOrCreate(): Creates or retrieves the SparkSession object'''
# Out:
#   File "<ipython-input-5-6c0317b37c52>", line 3
#     import pyspark.sql from SparkSession
#     ^
# IndentationError: unexpected indent

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.enableHiveSupport().master('local').getOrCreate()
'''
SparkContext operates at a lower level, dealing with RDDs and core Spark functionalities.
SparkSession provides a higher-level abstraction, simplifying interactions with structured data.'''


sc = spark.sparkContext
x = [ 'a', 'b', 'c', 'd' ,'e']
type (x);

dataset1 = sc.parallelize(x)
print(dataset1)
# Out:
# ParallelCollectionRDD[2] at readRDDFromFile at PythonRDD.scala:289
